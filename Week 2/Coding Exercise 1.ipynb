# %% [markdown]
# # Coding Exercise 1
#
# <font color='red'><b>
# After you complete the assignment, before submission, restart the kernel and re-execute the code. Do this for each code cell. This is to reset all the variables and ensure the execution order will be the same as that in the grader. It is very important to do this for every assignment before submission.
#
# - Don't add/remove any cell in the notebook for the autograder to work. Don't remove any existing code (importing libraries, for example) in the provided template.
# - Follow the instruction closely. For example, use the exact same file names (to read from or write to) in the instruction. If you download a file more than once, your computer will add numbers to the file name. You should remove the numbers to make sure the file name is not altered.
# - All or part of your output must be exactly like the provided examples (follow the instruction of each question).
# - If you are using any packages or libraries not provided in the template, you MUST import them to every cell using the libraries.
# - Ask for clarification for anything unclear.</b></font>

# %% [markdown]
# ## Question 1: Temperature converter
#
# 1. Use input() to get user input for the current temperature in Fahrenheit. Use a proper prompt so the user knows what you are asking for.
# 1. Convert the user input into a <b>float</b> and save it to a variable named "fahrenheit". As long as the user enters a number, the code should work.
# 1. Convert the fahrenheit temperature entered by the user into celsuis temperature and store it in a variable named "celsuis". The formula is:
# <pre>
#     celsuis = (fahrenheit − 32) × 5/9 </pre>
# 1. Check celsuis for the following conditions and print out corresponding messages
#    - check if celsuis is less than equal to 0, if so, print out "Freezing!"
#    - check if celsuis is less than equal to 18, if so, print out "Chilly!"
#    - check if celsuis is less than equal to 28, if so, print out "Comfy!"
#    - check if celsuis is less than equal to 35, if so, print out "Hot!"
#    - check if celsuis is less than equal to 18, if so, print out "sweltering!"
# 1. Print out the entered Fahrehheit and the converted Celsuis. For example, if the user enters 68, the following should be the output
# <pre>
# Tell me the temperature in Fahrenheit: 68
# Comfy!
# Fahrenheit entered: 68.0  celsuis: 20.0
# </pre>
# 1. Another test case is converting 30 in Fahrenheit. The output should be the following. The many digits after the decimal point is fine. **Don't round it.**:
# <pre>
# Tell me the temperature in Fahrenheit: 30
# Freezing!
# Fahrenheit entered: 30.0  celsuis: -1.1111111111111112
# </pre>
# 1. You should try all the branches of the if statement to ensure all your code are correct.
# 1. Feel free to use comments as you see fit

# %%
### Enter your code for Question 1 in this cell ONLY ###

fahrenheit = float(input("Tell me the temperature in Fahrenheit: ").strip())


def q1(fahrenheit):
    celsuis = (fahrenheit - 32) * 5/9
    if celsuis <= 0:
        print("Freezing!")
    elif celsuis <= 18:
        print("Chilling!")
    elif celsuis <= 28:
        print("Comfy!")
    elif celsuis <= 35:
        print("Hot!")
    # Instructions claim that this should be [celsuis <= 18] which will never be reached.
    else:
        print("sweltering!")

    print(f"Fahrenheit entered: {fahrenheit}  celsuis: {celsuis}")


q1(fahrenheit)


def q1_test():
    for iterator in range(-10, 200, 10):
        q1(iterator)


# q1_test()
# Out:
# Comfy!
# Fahrenheit entered: 78.0  celsuis: 25.555555555555557

# %% [markdown]
# ## Question 2: Admission decision using if statement
#
# Write some code to decide whether to admit a student or not. (Please note that the criteria are completely made up for the purpose of practice coding.) 4 inputs are needed:
#
# 1. High school GPA. This should be a positive float
# 1. SAT. This sould be a positive integer
# 1. Volunteer hours. This sould be a positive integer
# 1. Number of other talents. This sould be a positive integer
#
# Based on the inputs, use if statements to make a decision on whether to admit a person.
#
# 1. If any of the input is negative, print: <b>"Sorry, at least one of the values you entered is incorrect. Try again"</b>.
# 1. if GPA is not lower than 3.8 and SAT is not lower than 1200, print: <b>"Congratulations, you are admitted!"</b>
# 1. Otherwise, if GPA is not lower than 3.8 and volunteer hours is not lower than 50 and number of other talents are more than 2, print: <b>"Congratulations, you are admitted!"</b>
# 1. Otherwise, if GPA is not lower than 4 and volunteer hours is not lower than 40 and number of other talents are more than 2, print: <b>"Congratulations, you are admitted!"</b>
# 1. Otherwise, if GPA is not lower than 3.8 and volunteer hours is not lower than 50, or GPA is not lower than 3.8 and number of other talents are more than 2, print: <b>"You are now placed on the waitlist"</b>
# 1. Otherwise, print <b>"Sorry, you are not admitted"</b>
#
# <b>Make sure your printout matches the respective text exactly. Wrong spelling will cost you points due to the nature of autograder. Don't use loop for this problem. If the user entered invalid values, she can just rerun the code</b>
#
# Some example inputs and results can be seen below (Not all scenarios are provided but you certainly should test each branch):
#
# <pre>
# Enter your high school GAP as a positive number: 3.9
# Enter you SAT as a positive integer: 1230
# Enter your volunteer hours a positive integer 1
# Enter your other talents as a positive integer -9
# Sorry, at least one of the values you entered is incorrect. Try again
#
# Enter your high school GAP as a positive number: 3.8
# Enter you SAT as a positive integer: 1300
# Enter your volunteer hours a positive integer 30
# Enter your other talents as a positive integer 2
# Congratulations, you are admitted!
# </pre>
#
# Hint: Don't use loop. Use a combination of nested if and if...elif to make the code to write. Rememeber than if one of the input is negative, your code should immediately end without checking other conditions.

# %%
### Enter your code for Question 3 in this cell ONLY ###

def validate_input(unvalidated_input):
    try:
        return float(unvalidated_input) >= 0
    except:
        return False


required_values = {"GPA": -1, "SAT": -1,
                   "Volunteer Hours": -1, "Talent Count": -1}

# I don't know why I chose to do this... I could have made a dictionary, iterated over keys. actually i'm gonna do that.


def get_valid_input(key):
    while True:
        required_values[key] = input(f"Please enter your {key}").strip()
        if validate_input(required_values[key]):
            required_values[key] = float(required_values[key])
            break
        else:
            print("Sorry, at least one of the values you entered is incorrect. Try again")
            break
            # This would allow for the program to run untill valid input is entered.
            # However, fear of the auto_grader is making me comment this out.

            # f"Sorry the {key} ({required_values[key]}) was entered incorrectly. Please try again.")


for key in required_values:
    get_valid_input(key)
    if key == 'GPA':
        pass
    else:
        # Even though this doesn't actually save any memory in the program (pretty sure ints and floats default to 64 bits regardless), placing this here for grading purposes.
        required_values[key] = int(required_values[key])


gpa = required_values['GPA']
sat = required_values['SAT']
volunteer_hours = required_values['Volunteer Hours']
talent_count = required_values['Talent Count']

if (gpa >= 0) and (sat >= 0) and (volunteer_hours >= 0) and (talent_count >= 0):

    if gpa >= 3.8 and sat >= 1200:
        print("Congratulations, you are admitted!")
    elif gpa >= 3.8 and volunteer_hours >= 50 and talent_count > 2:
        print("Congratulations, you are admitted!")
    elif gpa >= 4 and volunteer_hours >= 40 and talent_count > 2:
        print("Congratulations, you are admitted!")
    elif (gpa >= 3.8 and volunteer_hours >= 50) or (gpa >= 3.8 and talent_count > 2):
        print("You are now placed on the waitlist")
    else:
        print("Sorry you are not admitted")
else:
    # I already have a print statement, this whole thing is just to not make auto grader angry.
    pass
# Out:
# Congratulations, you are admitted!

# %%
# #### Drafted Trash Code

# ```python
# #Nightmare Below please minimize
#  # GPA
#  while True:
#      gpa_test = input("Please enter your GPA").strip()
#      if validate_input(gpa_test):
#          gpa_test = float(gpa_test)
#          break
#      else:
#          print(
#              f"Sorry the GPA ({gpa_test}) was entered incorrectly. Please try again.")
#  # SAT
#  while True:
#      sat_test = (input("Please enter your SAT score").strip())
#      if validate_input(sat_test):
#          sat_test = int(sat_test)
#          break
#      else:
#          print(
#              f"Sorry the SAT score({sat_test}) was entered incorrectly. Please try again.")
#  # Volunteer Hours
#  while True:
#      volunteer_hours = (input("Please enter your Volunteer Hours").strip())
#      if validate_input(volunteer_hours):
#          volunteer_hours = int(volunteer_hours)
#          break
#      else:
#          print(
#              f"Sorry the Volunteer hours ({volunteer_hours}) were entered incorrectly. Please try again.")
#  # Talent number
#  while True:
#      num_of_talents = (input("Please enter your Talent Count").strip())
#      if validate_input(num_of_talents):
#          num_of_talents = int(num_of_talents)
#          break
#      else:
#          print(
#              f"Sorry the Talent Count ({num_of_talents}) was entered incorrectly. Please try again.")#             f"Sorry the Talent Count ({num_of_talents}) was entered incorrectly. Please try again.")
# ```
